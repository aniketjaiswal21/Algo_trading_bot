# %% [markdown]
# # Generalization with OOP: The MLBacktester Class

# %% [markdown]
# ## Using the MLBacktester Class

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
plt.style.use("seaborn")

# %%
df = pd.read_csv("five_minute_pairs.csv", parse_dates = ["time"], index_col = "time")
df
# Out:
#                              EURUSD    GBPUSD    EURAUD
# time
# 2019-01-01 22:00:00+00:00  1.146580  1.274680  1.626230
# 2019-01-01 22:05:00+00:00  1.146350  1.274270  1.626170
# 2019-01-01 22:10:00+00:00  1.146320  1.274760  1.626290
# 2019-01-01 22:15:00+00:00  1.146320  1.274770  1.626290
# 2019-01-01 22:20:00+00:00  1.146530  1.274760  1.625620
# ...                             ...       ...       ...
# 2020-08-30 23:35:00+00:00  1.190895  1.335140  1.617190
# 2020-08-30 23:40:00+00:00  1.191240  1.335250  1.616890
# 2020-08-30 23:45:00+00:00  1.191515  1.335515  1.616870
# 2020-08-30 23:50:00+00:00  1.191685  1.335580  1.617060
# 2020-08-30 23:55:00+00:00  1.191715  1.335490  1.616945
#
# [124056 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 124056 entries, 2019-01-01 22:00:00+00:00 to 2020-08-30 23:55:00+00:00
# Data columns (total 3 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   EURUSD  123350 non-null  float64
#  1   GBPUSD  123169 non-null  float64
#  2   EURAUD  123742 non-null  float64
# dtypes: float64(3)
# memory usage: 3.8 MB

# %%
import MLBacktester as MLB

# %% [markdown]
# ### EURUSD

# %%
symbol = "EURUSD"

# %%
ptc = 0.00007

# %%
ml = MLB.MLBacktester(symbol, "2019-01-01", "2020-08-31", ptc)

# %%
ml
# Out:
# MLBacktester(symbol = EURUSD, start = 2019-01-01, end = 2020-08-31, tc = 7e-05)

# %%
ml.data
# Out:
#                               price   returns
# time
# 2019-01-01 22:00:00+00:00  1.146580       NaN
# 2019-01-01 22:05:00+00:00  1.146350 -0.000201
# 2019-01-01 22:10:00+00:00  1.146320 -0.000026
# 2019-01-01 22:15:00+00:00  1.146320  0.000000
# 2019-01-01 22:20:00+00:00  1.146530  0.000183
# ...                             ...       ...
# 2020-08-30 23:35:00+00:00  1.190895 -0.000080
# 2020-08-30 23:40:00+00:00  1.191240  0.000290
# 2020-08-30 23:45:00+00:00  1.191515  0.000231
# 2020-08-30 23:50:00+00:00  1.191685  0.000143
# 2020-08-30 23:55:00+00:00  1.191715  0.000025
#
# [123350 rows x 2 columns]

# %%
ml.test_strategy(train_ratio = 0.7, lags = 5)
# Out:
# (0.176822, -0.893132)

# %%
ml.plot_results()

# %%
ml.results
# Out:
#                               price   returns      lag1      lag2      lag3  \
# time
# 2020-03-03 00:20:00+00:00  1.113645 -0.000139 -0.000206 -0.000135 -0.000265
# 2020-03-03 00:25:00+00:00  1.113745  0.000090 -0.000139 -0.000206 -0.000135
# 2020-03-03 00:30:00+00:00  1.113755  0.000009  0.000090 -0.000139 -0.000206
# 2020-03-03 00:35:00+00:00  1.113770  0.000013  0.000009  0.000090 -0.000139
# 2020-03-03 00:40:00+00:00  1.113450 -0.000287  0.000013  0.000009  0.000090
# ...                             ...       ...       ...       ...       ...
# 2020-08-30 23:35:00+00:00  1.190895 -0.000080 -0.000092  0.000298  0.000046
# 2020-08-30 23:40:00+00:00  1.191240  0.000290 -0.000080 -0.000092  0.000298
# 2020-08-30 23:45:00+00:00  1.191515  0.000231  0.000290 -0.000080 -0.000092
# 2020-08-30 23:50:00+00:00  1.191685  0.000143  0.000231  0.000290 -0.000080
# 2020-08-30 23:55:00+00:00  1.191715  0.000025  0.000143  0.000231  0.000290
#
#                                lag4      lag5  pred  strategy  trades  \
# time
# 2020-03-03 00:20:00+00:00  0.000027  0.000058   1.0 -0.000139     0.0
# 2020-03-03 00:25:00+00:00 -0.000265  0.000027   1.0  0.000090     0.0
# 2020-03-03 00:30:00+00:00 -0.000135 -0.000265   1.0  0.000009     0.0
# 2020-03-03 00:35:00+00:00 -0.000206 -0.000135   1.0  0.000013     0.0
# 2020-03-03 00:40:00+00:00 -0.000139 -0.000206   1.0 -0.000287     0.0
# ...                             ...       ...   ...       ...     ...
# 2020-08-30 23:35:00+00:00  0.000000 -0.000151   1.0 -0.000220     2.0
# 2020-08-30 23:40:00+00:00  0.000046  0.000000   1.0  0.000290     0.0
# 2020-08-30 23:45:00+00:00  0.000298  0.000046  -1.0 -0.000371     2.0
# 2020-08-30 23:50:00+00:00 -0.000092  0.000298  -1.0 -0.000143     0.0
# 2020-08-30 23:55:00+00:00 -0.000080 -0.000092  -1.0 -0.000025     0.0
#
#                            creturns  cstrategy
# time
# 2020-03-03 00:20:00+00:00  0.999861   0.999861
# 2020-03-03 00:25:00+00:00  0.999951   0.999951
# 2020-03-03 00:30:00+00:00  0.999960   0.999960
# 2020-03-03 00:35:00+00:00  0.999973   0.999973
# 2020-03-03 00:40:00+00:00  0.999686   0.999686
# ...                             ...        ...
# 2020-08-30 23:35:00+00:00  1.069218   0.176866
# 2020-08-30 23:40:00+00:00  1.069528   0.176917
# 2020-08-30 23:45:00+00:00  1.069775   0.176852
# 2020-08-30 23:50:00+00:00  1.069927   0.176826
# 2020-08-30 23:55:00+00:00  1.069954   0.176822
#
# [37001 rows x 12 columns]

# %% [markdown]
# __The optimal Number of Lags__

# %%
for lags in range(1, 21):
    print(lags, ml.test_strategy(train_ratio = 0.7, lags = lags))
# Out:
# 1 (0.099865, -0.96947)
# 2 (0.155496, -0.91381)
# 3 (0.152651, -0.916938)
# 4 (0.166359, -0.903375)
# 5 (0.176822, -0.893132)
# 6 (0.182555, -0.887548)
# 7 (0.18158, -0.888427)
# 8 (0.182021, -0.887977)
# 9 (0.192528, -0.877455)
# 10 (0.185703, -0.884588)
# 11 (0.191589, -0.878793)
# 12 (0.187334, -0.883111)
# 13 (0.185525, -0.884953)
# 14 (0.180646, -0.89)
# 15 (0.180219, -0.890533)
# 16 (0.178193, -0.893131)
# 17 (0.177386, -0.894054)
# 18 (0.179068, -0.89191)
# 19 (0.180449, -0.890399)
# 20 (0.180706, -0.890205)

# %%
ml.results.trades.value_counts()
# Out:
# 0.0    22711
# 2.0    14275
# Name: trades, dtype: int64

# %% [markdown]
# ### EURAUD

# %%
symbol = "EURAUD"

# %%
ml = MLB.MLBacktester(symbol, "2019-01-01", "2020-08-31", 0)

# %%
ml.test_strategy(train_ratio = 0.7, lags = 15)
# Out:
# (1.830543, 0.881757)

# %%
ml.plot_results()

# %% [markdown]
# __The optimal Number of Lags__

# %%
for lags in range(1, 21):
    print(lags, ml.test_strategy(train_ratio = 0.7, lags = lags))
# Out:
# 1 (1.618959, 0.669992)
# 2 (1.700957, 0.751976)
# 3 (1.688437, 0.738829)
# 4 (1.678823, 0.729776)
# 5 (1.568475, 0.619141)
# 6 (1.608623, 0.659603)
# 7 (1.609968, 0.660825)
# 8 (1.621555, 0.672797)
# 9 (1.677693, 0.729174)
# 10 (1.589426, 0.640069)
# 11 (1.669541, 0.720298)
# 12 (1.717291, 0.768219)
# 13 (1.758792, 0.809989)
# 14 (1.786919, 0.838177)
# 15 (1.830543, 0.881757)
# 16 (1.702411, 0.753792)
# 17 (1.610886, 0.662314)
# 18 (1.649278, 0.700481)
# 19 (1.670748, 0.721605)
# 20 (1.751434, 0.80169)

# %%
ml.results
# Out:
#                               price   returns      lag1      lag2      lag3  \
# time
# 2020-03-02 23:55:00+00:00  1.701685 -0.000482 -0.000634 -0.000364 -0.000238
# 2020-03-03 00:00:00+00:00  1.703020  0.000784 -0.000482 -0.000634 -0.000364
# 2020-03-03 00:05:00+00:00  1.703940  0.000540  0.000784 -0.000482 -0.000634
# 2020-03-03 00:10:00+00:00  1.703895 -0.000026  0.000540  0.000784 -0.000482
# 2020-03-03 00:15:00+00:00  1.703560 -0.000197 -0.000026  0.000540  0.000784
# ...                             ...       ...       ...       ...       ...
# 2020-08-30 23:35:00+00:00  1.617190 -0.000108  0.000040 -0.000043  0.000006
# 2020-08-30 23:40:00+00:00  1.616890 -0.000186 -0.000108  0.000040 -0.000043
# 2020-08-30 23:45:00+00:00  1.616870 -0.000012 -0.000186 -0.000108  0.000040
# 2020-08-30 23:50:00+00:00  1.617060  0.000118 -0.000012 -0.000186 -0.000108
# 2020-08-30 23:55:00+00:00  1.616945 -0.000071  0.000118 -0.000012 -0.000186
#
#                                lag4      lag5      lag6      lag7      lag8  \
# time
# 2020-03-02 23:55:00+00:00  0.000050  0.000176 -0.000047  0.000065  0.000285
# 2020-03-03 00:00:00+00:00 -0.000238  0.000050  0.000176 -0.000047  0.000065
# 2020-03-03 00:05:00+00:00 -0.000364 -0.000238  0.000050  0.000176 -0.000047
# 2020-03-03 00:10:00+00:00 -0.000634 -0.000364 -0.000238  0.000050  0.000176
# 2020-03-03 00:15:00+00:00 -0.000482 -0.000634 -0.000364 -0.000238  0.000050
# ...                             ...       ...       ...       ...       ...
# 2020-08-30 23:35:00+00:00  0.000012  0.000121  0.000099 -0.000083  0.000195
# 2020-08-30 23:40:00+00:00  0.000006  0.000012  0.000121  0.000099 -0.000083
# 2020-08-30 23:45:00+00:00 -0.000043  0.000006  0.000012  0.000121  0.000099
# 2020-08-30 23:50:00+00:00  0.000040 -0.000043  0.000006  0.000012  0.000121
# 2020-08-30 23:55:00+00:00 -0.000108  0.000040 -0.000043  0.000006  0.000012
#
#                            ...     lag16     lag17     lag18     lag19  \
# time                       ...
# 2020-03-02 23:55:00+00:00  ... -0.000302  0.000590 -0.000660 -0.000015
# 2020-03-03 00:00:00+00:00  ...  0.000332 -0.000302  0.000590 -0.000660
# 2020-03-03 00:05:00+00:00  ... -0.000129  0.000332 -0.000302  0.000590
# 2020-03-03 00:10:00+00:00  ...  0.000405 -0.000129  0.000332 -0.000302
# 2020-03-03 00:15:00+00:00  ...  0.000252  0.000405 -0.000129  0.000332
# ...                        ...       ...       ...       ...       ...
# 2020-08-30 23:35:00+00:00  ...  0.000232 -0.000111 -0.000142 -0.000257
# 2020-08-30 23:40:00+00:00  ...  0.000356  0.000232 -0.000111 -0.000142
# 2020-08-30 23:45:00+00:00  ...  0.000096  0.000356  0.000232 -0.000111
# 2020-08-30 23:50:00+00:00  ... -0.000464  0.000096  0.000356  0.000232
# 2020-08-30 23:55:00+00:00  ...  0.000170 -0.000464  0.000096  0.000356
#
#                               lag20  pred  strategy  trades  creturns  \
# time
# 2020-03-02 23:55:00+00:00 -0.000414   1.0 -0.000482     0.0  0.999518
# 2020-03-03 00:00:00+00:00 -0.000015   1.0  0.000784     0.0  1.000302
# 2020-03-03 00:05:00+00:00 -0.000660  -1.0 -0.000540     2.0  1.000843
# 2020-03-03 00:10:00+00:00  0.000590  -1.0  0.000026     0.0  1.000816
# 2020-03-03 00:15:00+00:00 -0.000302  -1.0  0.000197     0.0  1.000620
# ...                             ...   ...       ...     ...       ...
# 2020-08-30 23:35:00+00:00 -0.000294  -1.0  0.000108     0.0  0.949889
# 2020-08-30 23:40:00+00:00 -0.000257   1.0 -0.000186     2.0  0.949712
# 2020-08-30 23:45:00+00:00 -0.000142   1.0 -0.000012     0.0  0.949701
# 2020-08-30 23:50:00+00:00 -0.000111   1.0  0.000118     0.0  0.949812
# 2020-08-30 23:55:00+00:00  0.000232  -1.0  0.000071     2.0  0.949745
#
#                            cstrategy
# time
# 2020-03-02 23:55:00+00:00   0.999518
# 2020-03-03 00:00:00+00:00   1.000302
# 2020-03-03 00:05:00+00:00   0.999762
# 2020-03-03 00:10:00+00:00   0.999789
# 2020-03-03 00:15:00+00:00   0.999985
# ...                              ...
# 2020-08-30 23:35:00+00:00   1.751451
# 2020-08-30 23:40:00+00:00   1.751126
# 2020-08-30 23:45:00+00:00   1.751104
# 2020-08-30 23:50:00+00:00   1.751310
# 2020-08-30 23:55:00+00:00   1.751434
#
# [37104 rows x 27 columns]

# %%
hits = np.sign(ml.results.returns * ml.results.pred).value_counts()
hits
# Out:
#  1.0    19238
# -1.0    17725
#  0.0      141
# dtype: int64

# %%
hit_ratio = hits[1.0] / sum(hits)
hit_ratio
# Out:
# 0.5184885726606295
